# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot

from datetime import datetime as dt
# %matplotlib inline
to_float = lambda x: float(x.strip() or np.nan)
to_date = lambda x: dt.strptime(x, "%Y%m%d").toordinal()

dates, avg_temp, min_temp, max_temp = np.loadtxt('./data/KNMI.txt', delimiter=',', usecols=(1,11,12,14),
          converters={1: to_date, 11: to_float, 12: to_float, 14: to_float}, unpack=True,
                                                encoding='latin1', skiprows=1)

# %%
dtidx = pd.DatetimeIndex([dt.fromordinal(int(date)) for date in dates])
data = pd.Series(avg_temp * .1 , index=dtidx)
fig = plt.figure()
fig.add_subplot(211)
lag_plot(data)

plt.figure()
autocorrelation_plot(data)
plt.figure()
resampled=data.resample('A')
resampled.plot()
# Out:
# 1951-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1952-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1953-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1954-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1955-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1956-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1957-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1958-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1959-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1960-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1961-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1962-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1963-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1964-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1965-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1966-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1967-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1968-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1969-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1970-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1971-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1972-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1973-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1974-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1975-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1976-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1977-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1978-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1979-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1980-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
#                             ...
# 1990-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1991-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1992-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1993-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1994-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1995-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1996-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1997-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1998-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 1999-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2000-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2001-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2002-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2003-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2004-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2005-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2006-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2007-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2008-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2009-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2010-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2011-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2012-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2013-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2014-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2016-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2017-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2018-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# 2019-12-31    AxesSubplot(0.125,0.2;0.775x0.68)
# Freq: A-DEC, Length: 69, dtype: object
